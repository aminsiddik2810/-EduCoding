# %% [markdown]
# <a href="https://colab.research.google.com/github/aminsiddik2810/-EduCoding/blob/main/Pertemuan2_AminSiddikRangkuti_220401010124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =========================================================
# PERTEMUAN 2 - PENGANTAR DATA SCIENCE
# Nama : Amin Siddik Rangkuti
# NIM  : 220401010124
# =========================================================

# =========================
# SEL 1 : OUTPUT SEDERHANA
# =========================
print("Hello, Data Science!")
print("Notebook Pertemuan 2")
print("Amin Siddik Rangkuti - 220401010124")

# %%
# =========================
# SEL 2 : VARIABEL
# =========================
nama = "Amin Siddik Rangkuti"
nim = "220401010124"
prodi = "PJJ Informatika"
semester = 4

print("\nBIODATA MAHASISWA")
print("========================")
print("Nama      :", nama)
print("NIM       :", nim)
print("Prodi     :", prodi)
print("Semester  :", semester)

# %%
# =========================
# SEL 3 : TIPE DATA
# =========================
umur = 35
ipk = 4
aktif = True

print("\nTIPE DATA")
print("========================")
print("Umur      :", umur)
print("IPK       :", ipk)
print("Aktif     :", aktif)

# %%
# =========================
# SEL 4 : LIST
# =========================
tools = [
    "Python",
    "Google Colab",
    "Jupyter Notebook",
    "GitHub",
    "Pandas"
]

print("\nTOOLS DATA SCIENCE")
print("========================")

for i, tool in enumerate(tools, start=1):
    print(f"{i}. {tool}")

# %%
# =========================
# SEL 5 : OPERASI MATEMATIKA
# =========================
a = 20
b = 5

print("\nOPERASI MATEMATIKA")
print("========================")
print("Penjumlahan :", a + b)
print("Pengurangan :", a - b)
print("Perkalian   :", a * b)
print("Pembagian   :", a / b)

# %%
# =========================
# SEL 6 : PERCABANGAN
# =========================
nilai = 85

print("\nHASIL NILAI")
print("========================")

if nilai >= 80:
    print("Grade A")
elif nilai >= 70:
    print("Grade B")
else:
    print("Grade C")

# %%
# =========================
# SEL 7 : PERULANGAN
# =========================
print("\nPERULANGAN")
print("========================")

for i in range(1, 6):
    print("Perulangan ke-", i)

# %%
# =========================
# SEL 8 : FUNGSI
# =========================
def perkenalan(nama, nim):
    return f"Hai, saya {nama} dengan NIM {nim}"

hasil = perkenalan(
    "Amin Siddik Rangkuti",
    "220401010124"
)

print("\nFUNGSI")
print("========================")
print(hasil)

# %%
# =========================
# SEL 9 : DICTIONARY
# =========================
mahasiswa = {
    "nama": "Amin Siddik Rangkuti",
    "nim": "220401010124",
    "prodi": "PJJ Informatika"
}

print("\nDICTIONARY")
print("========================")

for key, value in mahasiswa.items():
    print(f"{key} : {value}")

# %%
# =========================
# SEL 10 : KESIMPULAN
# =========================
print("\n======================================")
print("Notebook Pertemuan 2 Berhasil Dijalankan")
print("Nama : Amin Siddik Rangkuti")
print("NIM  : 220401010124")
print("======================================")
