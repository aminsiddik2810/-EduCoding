# %% [markdown]
# <a href="https://colab.research.google.com/github/aminsiddik2810/-EduCoding/blob/main/Pertemuan1_AminSiddikRangkuti_220401010124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Amin Siddik Rangkuti"   # String
angkatan = 2022                 # Integer
ipk = 4                      # Float
aktif = True                    # Boolean

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan(
    "Amin Siddik Rangkuti",
    "PJJ Informatika",
    2022
)

print("\n" + hasil)

# %%
# SEL 5: Tambahan sesuai identitas mahasiswa
nim = "220401010124"
mata_kuliah = "Pengantar Data Science"

print("\n===================================")
print("BIODATA MAHASISWA")
print("===================================")
print(f"Nama         : {nama}")
print(f"NIM          : {nim}")
print(f"Program Studi: PJJ Informatika")
print(f"Mata Kuliah  : {mata_kuliah}")
print("===================================")
